# %%
import sys
sys.path
# Out:
# ['/opt/anaconda3/envs/dgai/lib/python312.zip',
#  '/opt/anaconda3/envs/dgai/lib/python3.12',
#  '/opt/anaconda3/envs/dgai/lib/python3.12/lib-dynload',
#  '',
#  '/opt/anaconda3/envs/dgai/lib/python3.12/site-packages']

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'import sys\nsys.path', 'locals()'],
#  '_oh': {1: ['/opt/anaconda3/envs/dgai/lib/python312.zip',
#    '/opt/anaconda3/envs/dgai/lib/python3.12',
#    '/opt/anaconda3/envs/dgai/lib/python3.12/lib-dynload',
#    '',
#    '/opt/anaconda3/envs/dgai/lib/python3.12/site-packages']},
#  '_dh': [PosixPath('/Users/heshuhua/lab/ailab/llmlab/pythonlab')],
#  'In': ['', 'import sys\nsys.path', 'locals()'],
#  'Out': {1: ['/opt/anaconda3/envs/dgai/lib/python312.zip',
#    '/opt/anaconda3/envs/dgai/lib/python3.12',
#    '/opt/anaconda3/envs/dgai/lib/python3.12/lib-dynload',
#    '',
#    '/opt/anaconda3/envs/dgai/lib/python3.12/site-packages']},
# ...

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'import sys\nsys.path', 'locals()', 'global', 'globals()'],
#  '_oh': {1: ['/opt/anaconda3/envs/dgai/lib/python312.zip',
#    '/opt/anaconda3/envs/dgai/lib/python3.12',
#    '/opt/anaconda3/envs/dgai/lib/python3.12/lib-dynload',
#    '',
#    '/opt/anaconda3/envs/dgai/lib/python3.12/site-packages'],
#   2: {...}},
#  '_dh': [PosixPath('/Users/heshuhua/lab/ailab/llmlab/pythonlab')],
#  'In': ['', 'import sys\nsys.path', 'locals()', 'global', 'globals()'],
#  'Out': {1: ['/opt/anaconda3/envs/dgai/lib/python312.zip',
#    '/opt/anaconda3/envs/dgai/lib/python3.12',
#    '/opt/anaconda3/envs/dgai/lib/python3.12/lib-dynload',
#    '',
#    '/opt/anaconda3/envs/dgai/lib/python3.12/site-packages'],
# ...

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_2',
#  '_4',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'open',
#  'quit',
#  'sys']

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...
