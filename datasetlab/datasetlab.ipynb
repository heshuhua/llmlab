# %% [markdown]
# ## 查看本地数据集

# %%
from datasets import load_dataset

# 假设你之前下载了 "squad" 数据集
dataset = load_dataset("cmrc2018", split="train") 

# 查看数据集的基本信息
print(dataset)
# Output: Dataset({
#    features: ['id', 'title', 'context', 'question', 'answers'],
#    num_rows: 87599
# })

# 查看数据集的特征（列名和数据类型）
print(dataset.features)

# 查看数据集的前几行
print(dataset[0]) # 查看第一行数据
print(dataset[:5]) # 查看前五行数据
